# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv("/content/drive/MyDrive/election2024dataset.csv")

# %%
df
# Out:
#                     id     sex  age federal_district  \
# 0     07169ed8148ce047    male   18  north caucasian
# 1     0716a4f3354cecdd    male   23  north caucasian
# 2     0716889b304ce79c    male   20            volga
# 3     07168e28b5cce563    male   22     northwestern
# 4     0716a563914ce549    male   21         southern
# ...                ...     ...  ...              ...
# 1595  0716b23c2c0cee3a    male   61          central
# 1596  07168254d14ceb55  female   80            volga
# 1597  071690f34d4ce164  female   76     northwestern
# 1598  0716bfa9c48ce79a  female   74          central
# 1599  07168088318cef88  female   76             ural
#
#                                       type_of_city    knows_election_date  \
# 0                                          village     named correct date
# 1                                          village     named correct date
# 2            city with population of less than 50k     named correct date
# ...

# %%
df.head()
# Out:
#                  id   sex  age federal_district  \
# 0  07169ed8148ce047  male   18  north caucasian
# 1  0716a4f3354cecdd  male   23  north caucasian
# 2  0716889b304ce79c  male   20            volga
# 3  07168e28b5cce563  male   22     northwestern
# 4  0716a563914ce549  male   21         southern
#
#                                    type_of_city    knows_election_date  \
# 0                                       village     named correct date
# 1                                       village     named correct date
# 2         city with population of less than 50k     named correct date
# 3  city with population of 1 million and higher  not sure or no answer
# 4  city with population of 1 million and higher     named correct date
#
#         will_vote candidate      television_usage      internet_usage  \
# 0        not sure     Putin  several times a week  over 4 hours a day
# 1        not sure     Putin      once half a year  over 4 hours a day
# ...

# %%
df.tail()
# Out:
#                     id     sex  age federal_district  \
# 1595  0716b23c2c0cee3a    male   61          central
# 1596  07168254d14ceb55  female   80            volga
# 1597  071690f34d4ce164  female   76     northwestern
# 1598  0716bfa9c48ce79a  female   74          central
# 1599  07168088318cef88  female   76             ural
#
#                                type_of_city    knows_election_date  \
# 1595                             settlement     named correct date
# 1596                                village     named correct date
# 1597        city with population of 50-100k     named correct date
# 1598  city with population of less than 50k  not sure or no answer
# 1599                                village     named correct date
#
#            will_vote           candidate      television_usage  \
# 1595   definitely no  will not take part    over 4 hours a day
# 1596      likely yes  struggle to answer  several times a week
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1600 entries, 0 to 1599
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   1600 non-null   object
#  1   sex                  1600 non-null   object
#  2   age                  1600 non-null   int64
#  3   federal_district     1600 non-null   object
#  4   type_of_city         1600 non-null   object
#  5   knows_election_date  1600 non-null   object
#  6   will_vote            1600 non-null   object
#  7   candidate            1600 non-null   object
#  8   television_usage     1600 non-null   object
#  9   internet_usage       1600 non-null   object
#  10  education            1600 non-null   object
#  11  income               1600 non-null   object
#  12  employment           1600 non-null   object
#  13  job_type             692 non-null    object
#  14  company_type         879 non-null    object
# ...

# %%
df.describe()
# Out:
#                age      weight1
# count  1600.000000  1600.000000
# mean     49.936250     1.000000
# std      16.901797     0.327084
# min      18.000000     0.468226
# 25%      37.000000     0.772224
# 50%      49.000000     0.921724
# 75%      64.000000     1.158913
# max      90.000000     2.515072

# %%
df.shape
# Out:
# (1600, 16)

# %%
df.isnull().sum()
# Out:
# id                       0
# sex                      0
# age                      0
# federal_district         0
# type_of_city             0
# knows_election_date      0
# will_vote                0
# candidate                0
# television_usage         0
# internet_usage           0
# education                0
# income                   0
# employment               0
# job_type               908
# company_type           721
# weight1                  0
# dtype: int64

# %%
df['job_type'] = df['job_type'].fillna(df['job_type'].mode(0))
df['job_type'] = df['job_type'].astype('category')
df['job_type'] = df['job_type'].cat.codes

# %%
df['company_type'] = df['company_type'].fillna(df['company_type'].mode(0))
df['company_type'] = df['company_type'].astype('category')
df['company_type'] = df['company_type'].cat.codes

# %%
df.isnull().sum()
# Out:
# id                     0
# sex                    0
# age                    0
# federal_district       0
# type_of_city           0
# knows_election_date    0
# will_vote              0
# candidate              0
# television_usage       0
# internet_usage         0
# education              0
# income                 0
# employment             0
# job_type               0
# company_type           0
# weight1                0
# dtype: int64

# %%
df.hist(figsize =(15,12))
# Out:
# array([[<Axes: title={'center': 'age'}>,
#         <Axes: title={'center': 'job_type'}>],
#        [<Axes: title={'center': 'company_type'}>,
#         <Axes: title={'center': 'weight1'}>]], dtype=object)

# %%
sns.boxplot(data = df, x = 'age', y = 'television_usage')
# Out:
# <Axes: xlabel='age', ylabel='television_usage'>

# %%
sns.boxplot(data = df, x = 'will_vote', y = 'age')
# Out:
# <Axes: xlabel='will_vote', ylabel='age'>

# %%
sns.pairplot(df)

# %%
#Label Encoding
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['will_vote'] = le.fit_transform(df['will_vote'])
df['age'] = le.fit_transform(df['age'])
df['sex'] = le.fit_transform(df['sex'])
df['job_type'] = le.fit_transform(df['job_type'])
df['company_type'] = le.fit_transform(df['company_type'])
df['television_usage'] = le.fit_transform(df['television_usage'])
df.head()
# Out:
#                  id  sex  age federal_district  \
# 0  07169ed8148ce047    1    0  north caucasian
# 1  0716a4f3354cecdd    1    5  north caucasian
# 2  0716889b304ce79c    1    2            volga
# 3  07168e28b5cce563    1    4     northwestern
# 4  0716a563914ce549    1    3         southern
#
#                                    type_of_city    knows_election_date  \
# 0                                       village     named correct date
# 1                                       village     named correct date
# 2         city with population of less than 50k     named correct date
# 3  city with population of 1 million and higher  not sure or no answer
# 4  city with population of 1 million and higher     named correct date
#
#    will_vote candidate  television_usage      internet_usage  \
# 0          4     Putin                 5  over 4 hours a day
# 1          4     Putin                 2  over 4 hours a day
# 2          1     Putin                 5  over 4 hours a day
# ...

# %%
df['education'] = le.fit_transform(df['education'])
df.head()
# Out:
#                  id  sex  age federal_district  \
# 0  07169ed8148ce047    1    0  north caucasian
# 1  0716a4f3354cecdd    1    5  north caucasian
# 2  0716889b304ce79c    1    2            volga
# 3  07168e28b5cce563    1    4     northwestern
# 4  0716a563914ce549    1    3         southern
#
#                                    type_of_city    knows_election_date  \
# 0                                       village     named correct date
# 1                                       village     named correct date
# 2         city with population of less than 50k     named correct date
# 3  city with population of 1 million and higher  not sure or no answer
# 4  city with population of 1 million and higher     named correct date
#
#    will_vote candidate  television_usage      internet_usage  education  \
# 0          4     Putin                 5  over 4 hours a day          3
# 1          4     Putin                 2  over 4 hours a day          2
# ...

# %%
x = df[['age','sex','education','job_type','company_type', 'television_usage']]
y = df['will_vote']

# %%
x
# Out:
#       age  sex  education  job_type  company_type  television_usage
# 0       0    1          3         0             6                 5
# 1       5    1          2         1            19                 2
# 2       2    1          2         5            12                 5
# 3       4    1          2         0             0                 5
# 4       3    1          1         1            18                 0
# ...   ...  ...        ...       ...           ...               ...
# 1595   43    1          1         0             0                 3
# 1596   62    0          2         0             0                 5
# 1597   58    0          1         0             0                 0
# 1598   56    0          0         1            11                 3
# 1599   58    0          5         0             0                 3
#
# [1600 rows x 6 columns]

# %%
y
# Out:
# 0       4
# 1       4
# 2       1
# 3       4
# 4       1
#        ..
# 1595    0
# 1596    3
# 1597    1
# 1598    1
# 1599    1
# Name: will_vote, Length: 1600, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 1)

# %%
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((1120, 6), (1120,), (480, 6), (480,))

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
#print matrix to get performance
from sklearn.metrics import accuracy_score
print(accuracy_score(y_train, lr.predict(x_train)))
# Out:
# 0.6580357142857143

# %%
# knn - k-nearest neighbour
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier()
model.fit(x_train, y_train)
# Out:
# KNeighborsClassifier()
