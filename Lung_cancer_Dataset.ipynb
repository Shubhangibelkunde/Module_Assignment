# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('/content/drive/MyDrive/lung_cancer_examples dataset.csv')

# %%
df
# Out:
#            Name      Surname  Age  Smokes  AreaQ  Alkhol  Result
# 0          John         Wick   35       3      5       4       1
# 1          John  Constantine   27      20      2       5       1
# 2        Camela     Anderson   30       0      5       2       0
# 3          Alex       Telles   28       0      8       1       0
# 4         Diego     Maradona   68       4      5       6       1
# 5     Cristiano      Ronaldo   34       0     10       0       0
# 6        Mihail          Tal   58      15     10       0       0
# 7         Kathy        Bates   22      12      5       2       0
# 8        Nicole       Kidman   45       2      6       0       0
# 9           Ray      Milland   52      18      4       5       1
# 10      Fredric        March   33       4      8       0       0
# 11          Yul      Brynner   18      10      6       3       0
# 12         Joan     Crawford   25       2      5       1       0
# ...

# %%
df.head()
# Out:
#      Name      Surname  Age  Smokes  AreaQ  Alkhol  Result
# 0    John         Wick   35       3      5       4       1
# 1    John  Constantine   27      20      2       5       1
# 2  Camela     Anderson   30       0      5       2       0
# 3    Alex       Telles   28       0      8       1       0
# 4   Diego     Maradona   68       4      5       6       1

# %%
df.tail()
# Out:
#          Name   Surname  Age  Smokes  AreaQ  Alkhol  Result
# 54    Ernest   Borgnine   26      13      6       1       0
# 55      Alec   Guinness   77      20      5       4       1
# 56  Charlton     Heston   75      15      3       5       1
# 57   Gregory       Peck   43      30      3       8       1
# 58    Sidney    Poitier   51      25      9       0       0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59 entries, 0 to 58
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Name     59 non-null     object
#  1   Surname  59 non-null     object
#  2   Age      59 non-null     int64
#  3   Smokes   59 non-null     int64
#  4   AreaQ    59 non-null     int64
#  5   Alkhol   59 non-null     int64
#  6   Result   59 non-null     int64
# dtypes: int64(5), object(2)
# memory usage: 3.4+ KB

# %%
df.describe()
# Out:
#              Age     Smokes      AreaQ     Alkhol     Result
# count  59.000000  59.000000  59.000000  59.000000  59.000000
# mean   42.627119  15.067797   5.203390   3.237288   0.474576
# std    16.235230   7.984607   2.461984   2.380517   0.503640
# min    18.000000   0.000000   1.000000   0.000000   0.000000
# 25%    29.000000  10.000000   3.000000   1.000000   0.000000
# 50%    39.000000  15.000000   5.000000   3.000000   0.000000
# 75%    55.000000  20.000000   7.500000   5.000000   1.000000
# max    77.000000  34.000000  10.000000   8.000000   1.000000

# %%
df.shape
# Out:
# (59, 7)

# %%
df.columns
# Out:
# Index(['Name', 'Surname', 'Age', 'Smokes', 'AreaQ', 'Alkhol', 'Result'], dtype='object')

# %% [markdown]
# PreProcessing of Dataset

# %%
df.isnull().sum() #checking if there is any missing value
# Out:
# Name       0
# Surname    0
# Age        0
# Smokes     0
# AreaQ      0
# Alkhol     0
# Result     0
# dtype: int64

# %%
#to display no.of samples on each class
df['Result'].value_counts()
# Out:
# Result
# 0    31
# 1    28
# Name: count, dtype: int64

# %% [markdown]
# EDA

# %%
df['Alkhol'].hist()
# Out:
# <Axes: >

# %% [markdown]
# There is no null value or missing value in dataset

# %%
df.hist(figsize =(15,12))
# Out:
# array([[<Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'Smokes'}>],
#        [<Axes: title={'center': 'AreaQ'}>,
#         <Axes: title={'center': 'Alkhol'}>],
#        [<Axes: title={'center': 'Result'}>, <Axes: >]], dtype=object)

# %%
sns.boxplot(data = df, x = 'Age', y = 'Alkhol')
# Out:
# <Axes: xlabel='Age', ylabel='Alkhol'>

# %%
sns.pairplot(df)

# %%
#Scatterplot
colors = ['red', 'blue']
sns.scatterplot(x = 'Age', y = 'Alkhol', data = df, hue = 'Result', palette = colors)
# Out:
# <Axes: xlabel='Age', ylabel='Alkhol'>

# %%
colors = ['red', 'blue']
sns.scatterplot(x = 'Age', y = 'Smokes', data = df, hue = 'Result', palette = colors)
# Out:
# <Axes: xlabel='Age', ylabel='Smokes'>

# %% [markdown]
# Model training

# %%
x = df[['Age', 'Alkhol', 'Smokes', 'AreaQ', 'Alkhol']]
y = df['Result']

# %%
x
# Out:
#     Age  Alkhol  Smokes  AreaQ  Alkhol
# 0    35       4       3      5       4
# 1    27       5      20      2       5
# 2    30       2       0      5       2
# 3    28       1       0      8       1
# 4    68       6       4      5       6
# 5    34       0       0     10       0
# 6    58       0      15     10       0
# 7    22       2      12      5       2
# 8    45       0       2      6       0
# 9    52       5      18      4       5
# 10   33       0       4      8       0
# 11   18       3      10      6       3
# 12   25       1       2      5       1
# 13   28       8      20      2       8
# 14   34       8      25      4       8
# 15   39       1      18      8       1
# 16   42       5      22      3       5
# 17   19       0      12      8       0
# 18   62       3       5      4       3
# 19   73       6      10      7       6
# 20   55       3      15      1       3
# 21   33       1       8      8       1
# 22   22       2      20      6       2
# ...

# %%
y
# Out:
# 0     1
# 1     1
# 2     0
# 3     0
# 4     1
# 5     0
# 6     0
# 7     0
# 8     0
# 9     1
# 10    0
# 11    0
# 12    0
# 13    1
# 14    1
# 15    0
# 16    1
# 17    0
# 18    1
# 19    1
# 20    1
# 21    0
# 22    0
# 23    0
# 24    1
# 25    0
# 26    0
# 27    0
# 28    1
# 29    1
# 30    0
# 31    1
# 32    1
# 33    1
# 34    0
# 35    0
# 36    1
# 37    1
# 38    0
# 39    0
# 40    1
# 41    0
# 42    1
# 43    1
# 44    0
# 45    0
# 46    0
# 47    0
# 48    1
# 49    1
# 50    0
# 51    1
# 52    1
# 53    0
# 54    0
# 55    1
# 56    1
# 57    1
# 58    0
# Name: Result, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 1)

# %%
x_train.shape
# Out:
# (41, 5)

# %%
y_train.shape
# Out:
# (41,)

# %%
x_test.shape
# Out:
# (18, 5)

# %%
#Logistic Regression
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
#print matrix to get performance
from sklearn.metrics import accuracy_score
print(accuracy_score(y_train, model.predict(x_train)))
# Out:
# 1.0

# %%
# knn - k-nearest neighbour
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier()
model.fit(x_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
print(accuracy_score(y_train, model.predict(x_train)))
# Out:
# 1.0

# %%
#Decision Tree
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()
model.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
print(accuracy_score(y_train, model.predict(x_train)))
# Out:
# 1.0
